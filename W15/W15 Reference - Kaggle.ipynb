# %% [markdown]
# # Reference - Kaggle Datasets
#
# With the Python basics and built-ins we've learned so far, it's now a good time to introduct [Kaggle](https://www.kaggle.com/) & [Kaggle Datasets](https://www.kaggle.com/datasets).

# %%
# Uncomment to install

#%pip install kagglehub

# %%
# If uncertain where you are, check current working directory

from pathlib import Path

print(Path.cwd())

# %%
# For download data to designated local directory, try below

import kagglehub

# Download latest version
path = kagglehub.dataset_download("ssssws/chocolate-sales-dataset-2023-2024", output_dir=Path.cwd() / "data" / "chocolate_sales")

print("Path to dataset files:", path)
